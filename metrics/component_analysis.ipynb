# %%
import sys
sys.path.append('../')

import utils
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import numpy as np

np.random.seed(42)
plt.style.use('../style.mpl')

# %%
G = utils.load_network(path="../data/network.pkl")
print(G)
# Out:
# Graph with 1139 nodes and 17908 edges

# %% [markdown]
# ## Component Analysis
#
# In this section, we explore the concept of connected components in the Spotify playlist graph. A component is a group of playlists where each one is directly or indirectly connected to the others. If a playlist is not connected to any others, it forms its own isolated component.
#
# By identifying these components, we can understand how well connected the overall playlist network is. The largest component usually represents the main "core" of the network, while smaller ones may reflect niche or isolated groups.
#
# This analysis helps reveal the structure and cohesion of the playlist ecosystem — whether it's mostly one big network, or fragmented into many small parts.

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 8), gridspec_kw={'width_ratios': [3, 1]})

# ---- Network plot (left)
pos = nx.spring_layout(G_largest, seed=42)
nx.draw_networkx_nodes(G_largest, pos, node_size=20, node_color='steelblue', alpha=0.8, ax=axs[0])
nx.draw_networkx_edges(G_largest, pos, edge_color='lightgray', alpha=0.4, ax=axs[0])
axs[0].axis("off")

# Title as text under the plot
axs[0].text(0.5, -0.1, "Largest Connected Component", fontsize=14, ha='center', transform=axs[0].transAxes)

# ---- Pie chart (right)
labels = ['Largest Component (100%)']
sizes = [len(G_largest)]
colors = ['steelblue']

axs[1].pie(
    sizes,
    labels=labels,
    colors=colors,
    autopct='%1.1f%%',
    startangle=90,
    textprops={'fontsize': 14}
)
axs[1].axis("equal")

# Title under the pie chart
axs[1].text(0.5, -0.1, "Proportion of Nodes in Largest Component", fontsize=14, ha='center', transform=axs[1].transAxes)

plt.tight_layout()
plt.show()

# %% [markdown]
# All playlists in this network are somehow connected — either directly or through shared artists. There are no isolated groups. This shows that the music ecosystem represented here is highly integrated and forms one large musical world.
